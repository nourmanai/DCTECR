# %%
# API KEY
#  AIzaSyChcKAIWtx3WIoDNQEsghaCMXS8YFlxPSo

# %%
import pymongo
con = pymongo.MongoClient("mongodb://localhost:27017/")
db = con.DCSTEC

# %%
db.list_collection_names()
# Out:
# ['News', 'Products']

# %%
db.News.count_documents({})
# Out:
# 100

# %%
youtube = db["Youtube"]

# %%
pip install google-api-python-client
# Out:
# ...
#      -------------------------------------- 11.4/11.4 MB 494.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 96.9/96.9 kB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 182.1/182.1 kB 1.4 MB/s eta 0:00:00
# ...
#      ------------------------------------ 120.5/120.5 kB 471.4 kB/s eta 0:00:00
# ...
#      -------------------------------------- 224.5/224.5 kB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 422.4/422.4 kB 1.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 181.3/181.3 kB 1.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 83.9/83.9 kB 134.6 kB/s eta 0:00:00Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)

# %%
pip install google-api-python-client google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from googleapiclient.discovery import build
from google.oauth2 import service_account

# %%
api_key = 'AIzaSyChcKAIWtx3WIoDNQEsghaCMXS8YFlxPSo'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def search_videos(query):
    try:
        request = youtube.search().list(
            part='snippet',
            q=query,
            type='video',
            maxResults=10
        )
        response = request.execute()
        return response['items']
    except HttpError as e:
        print('An error occurred:', e)
        return []

# %%
search_results = search_videos('svr skin product')
for video in search_results:
    print(video['snippet']['title'])
# Out:
# 🌟 TOP SVR  | La MEILLEURE MARQUE de Parapharmacie !
# SVR|MAT+PORES SEBIACLEAR #pores #skincare #acnetreatment #acne #shorts #svr #oilyskin #review
# SVR : LES MEILLEURS PRODUITS POUR HYDRATER, CICATRISER, DIMINUER LES BOUTONS, LES TACHES &amp; LES RIDES
# SVR SEBIACLEAR SPF 50 | skin test, short review &amp; INCI (ingredients)
# Filtr SPF50+ z efektem fotoshopa? #cococollection #cocopoleca #svr #filtrspf50
# SVR Sebiaclear Creme Daily Sunscreen SPF 50 | Ramon Recommended: Euro Edition
# SVR @ Care to Beauty
# روتين تفتيح البشرة وعلاج التصبغات اس في ار كليريال SVR CLARIAL Products Review
# Je vous parle de ma nouvelle routine avec la marque SVR 🌿🚿
# Acne… Tâches… Cicatrices #laterma #skincare #larocheposay #svr

# %%
video_url = 'https://www.youtube.com/watch?v=mP_F_-LjSEI'
video_id = get_video_id(video_url)
print(video_id)

def get_video_details(video_id):
    try:
        request = youtube.videos().list(
            part='snippet',
            id=video_id
        )
        response = request.execute()
        if 'items' in response:
            return response['items'][0]
        else:
            return None
    except HttpError as e:
        print('An error occurred:', e)
        return None
# Out:
# mP_F_-LjSEI

# %%
video_details = get_video_details(video_id)
if video_details:
    print('Title:', video_details['snippet']['title'])
    print('Description:', video_details['snippet']['description'])
    print('Tags:', video_details['snippet']['tags'])
# Out:
# Title: #ABtalks with Vishen Lakhiani - مع ڤيشين لاخيانى | Chapter 156
# Description: Vishen Lakhiani is an entrepreneur, motivational speaker, and author of ‘The 6 Phase Meditation Method’. On this upcoming episode of #ABtalks, we invite you to unravel the layers that make up Vishen, as we delve into the profound moments that shaped his journey. From his early battles with bullying, to his unique perspective on meditation, how he was able to have a peaceful divorce, and much more. Join us this Tuesday as we dig deep and discover the world of Vishen Lakhiani.
#
# #ABtalks is a YouTube interview show hosted by Anas Bukhash that shines the spotlight on the raw side of celebrities, influencers, and achievers as human beings.
#
# ...

# %%
pip install google-api-python-client google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

def get_channel_info(channel_id):
    try:
        # Create the YouTube Data API service object
        youtube = build('youtube', 'v3')

        # Request the channel information
        request = youtube.channels().list(
            part='snippet,statistics',
            id=channel_id
        )
        response = request.execute()

        if 'items' in response:
            return response['items'][0]
        else:
            return None
    except HttpError as e:
        print('An error occurred:', e)
        return None

# %%
pip install google-api-python-client google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)
# ...

# %%
channel_id = 'GOqEl4ADyVk'
channel_info = get_channel_info(channel_id)
if channel_info:
    print('Channel Title:', channel_info['snippet']['title'])
    print('Channel Description:', channel_info['snippet']['description'])
    print('Subscriber Count:', channel_info['statistics']['subscriberCount'])
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-88-0e2f0d2fe10b> in <module>
#       1 channel_id = 'GOqEl4ADyVk'
# ----> 2 channel_info = get_channel_info(channel_id)
#       3 if channel_info:
#       4     print('Channel Title:', channel_info['snippet']['title'])
#       5     print('Channel Description:', channel_info['snippet']['description'])
#
# <ipython-input-87-b63e9ff7109e> in get_channel_info(channel_id)
#       5     try:
#       6         # Create the YouTube Data API service object
# ----> 7         youtube = build('youtube', 'v3')
#       8
#       9         # Request the channel information
#
# ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# ...

# %%
def get_channel_details(channel_id):
    try:
        request = youtube.channels().list(
            part='snippet,contentDetails,statistics',
            id=channel_id
        )
        response = request.execute()
        if 'items' in response:
            print('there is items')
            return response['items'][0]
        else:
            print('items none')
            return None
        
    except HttpError as e:
        print('An error occurred:', e)
        return None

# %%
channel_id ='zGXGA1dMYu4'
channel_details = get_channel_details(channel_id)
if channel_details:
    print('Channel Title:', channel_details['snippet']['title'])
    print('Channel Description:', channel_details['snippet']['description'])
    print('Subscriber Count:', channel_details['statistics']['subscriberCount'])
else: 
    print('sorry not sorry')
# Out:
# items none
# sorry not sorry

# %%
import re
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

def get_channel_id(channel_url):
    # Extract the Channel ID from the URL
    pattern = r"(?<=channel\/|\/user\/|\/c\/|\/u\/)(\w+)"
    match = re.search(pattern, channel_url)
    if match:
        return match.group(1)
    else:
        return None

def get_channel_details(channel_id, api_key):
    try:
        # Build the YouTube Data API client
        youtube = build('youtube', 'v3', developerKey=api_key)

        # Retrieve channel details using the Channels API
        response = youtube.channels().list(
            part='snippet',
            id=channel_id
        ).execute()

        # Extract relevant channel details
        print(response['pageInfo'])
        channel_info = response['items'][0]
        
        channel_title = channel_info['snippet']['title']
        channel_description = channel_info['snippet']['description']
        channel_published_at = channel_info['publishedAt']

        return channel_title, channel_description, channel_published_at

    except HttpError as e:
        print('An error occurred:', e)
        return None

# %%
# Replace 'YOUR_API_KEY' with your own API key
api_key = 'AIzaSyChcKAIWtx3WIoDNQEsghaCMXS8YFlxPSo'

# Replace 'CHANNEL_URL' with the desired channel URL
channel_url = 'https://www.youtube.com/channel/UCvxd27yq1xlTSKH05k-0wKg'

# Get the Channel ID from the URL
#channel_id = get_channel_id(channel_url)
channel_id = 'UCvxd27yq1xlTSKH05k-0wKg'
if channel_id:
    # Get channel details using the API
    channel_details = get_channel_details(channel_id, api_key)
    if channel_details:
        channel_title, channel_description, channel_published_at = channel_details
        print('Channel Title:', channel_title)
        print('Channel Description:', channel_description)
        print('Channel Published At:', channel_published_at)
    else:
        print('Failed to retrieve channel details.')
else:
    print('Invalid channel URL.')
# Out:
# {'totalResults': 0, 'resultsPerPage': 5}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-163-97288493652c> in <module>
#      10 if channel_id:
#      11     # Get channel details using the API
# ---> 12     channel_details = get_channel_details(channel_id, api_key)
#      13     if channel_details:
#      14         channel_title, channel_description, channel_published_at = channel_details
#
# <ipython-input-162-d64d4fe4e29e> in get_channel_details(channel_id, api_key)
#      25         # Extract relevant channel details
#      26         print(response['pageInfo'])
# ---> 27         channel_info = response['items'][0]
#      28
#      29         channel_title = channel_info['snippet']['title']
#
# KeyError: 'items'

# %%
import re
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

#def get_channel_id(channel_url):
    # Extract the Channel ID from the URL
    #pattern = r"(?<=channel\/|\/user\/|\/c\/|\/u\/)(\w+)"
    #match = re.search(pattern, channel_url)
    #if match:
        #return match.group(1)
    #else:
        #return None
    
def get_channel_id(channel_url):
    # Extract the Channel ID from the URL
    pattern = r"(?:channel/|/user/|/c/|/u/)(\w+)"
    match = re.search(pattern, channel_url)
    if match:
        return match.group(1)
    else:
        return None

def get_channel_details(channel_id, api_key):
    try:
        # Build the YouTube Data API client
        youtube = build('youtube', 'v3', developerKey=api_key)

        # Retrieve channel details using the Channels API
        response = youtube.channels().list(
            part='snippet',
            id=channel_id
        ).execute()

        # Check if there are any items in the response
        if 'items' in response and len(response['items']) > 0:
            # Extract relevant channel details
            channel_info = response['items'][0]['snippet']
            channel_title = channel_info['title']
            channel_description = channel_info['description']
            channel_published_at = channel_info['publishedAt']

            return channel_title, channel_description, channel_published_at
        else:
            print('No channel details found.')
            return None

    except HttpError as e:
        print('An error occurred:', e)
        return None

# %%
# Replace 'YOUR_API_KEY' with your own API key
api_key = 'AIzaSyChcKAIWtx3WIoDNQEsghaCMXS8YFlxPSo'

# Replace 'CHANNEL_URL' with the desired channel URL
channel_url = 'https://www.youtube.com/channel/UCvxd27yq1xlTSKH05k-0wKg'
# Get the Channel ID from the URL
channel_id = get_channel_id(channel_url)

if channel_id:
    # Get channel details using the API
    channel_details = get_channel_details(channel_id, api_key)
    if channel_details:
        channel_title, channel_description, channel_published_at = channel_details
        print('Channel Title:', channel_title)
        print('Channel Description:', channel_description)
        print('Channel Published At:', channel_published_at)
    else:
        print('Failed to retrieve channel details.')
else:
    print('Invalid channel URL.')
# Out:
# No channel details found.
# Failed to retrieve channel details.
