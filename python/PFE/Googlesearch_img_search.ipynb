# %%
import requests
import json
import pandas as pd
from pandas import json_normalize
import pymongo
import sys

url = "https://google-search83.p.rapidapi.com/google"

script_argument = sys.argv[1]
querystring = {"query": script_argument, "gl": "us", "lr": "en", "num": "10", "start": "0"}

headers = {
    "X-RapidAPI-Key": "a619bfcad9msh56f2f66563cadb4p186d94jsn0a59d4ce6269",
    "X-RapidAPI-Host": "google-search83.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data_dict = json.loads(response.content)


print(data_dict )
# Out:
# Raw Response Content:
# ...

# %%
from pandas import json_normalize 

con = pymongo.MongoClient("mongodb://localhost:27017/")
db = con.DCSTEC
collection = db.ResearchResults
df_searchResults = json_normalize(data_dict)
data = df_searchResults.to_dict(orient='records')
collection.insert_many(data)
