# %%
# API KEY 
# 41bbcb537a604f77bc4b9329466ddea0

# %%
curl "https://api.webfinery.com/ranks?domain=http://artcom.com.tn&key=41bbcb537a604f77bc4b9329466ddea0"

# %%
import requests

# Set the endpoint URL
url = "https://api.webfinery.com/ranks"

# Set the query parameters
params = {
    'domain': 'amazon.com',
    'key': '41bbcb537a604f77bc4b9329466ddea0'
}

# Send a GET request to the API
response = requests.get(url, params=params)



# Print the response content
print(response.content)


# Check if the request was successful (HTTP status code 200)
if response.status_code == 200:
    # Parse the response JSON
    data = response.json()
    # Process the data as needed
    print(data)
else:
    # Handle the error
    print("Error:", response.status_code)
# Out:
# b'<html>\n    <style>\n        body {\n            font-family: sans-serif;\n            display: flex;\n            flex-direction: column;\n            align-items: center;\n            justify-content: center;\n            color: rgb(41, 41, 41);\n            height: 100vh;\n        }\n    </style>\n    <body>\n        <h1>404 Not found</h1>\n    </body>\n</html>'
# Error: 404

# %%
# n'est pas stable
