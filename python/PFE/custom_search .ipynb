# %%
# API key 
# AIzaSyChcKAIWtx3WIoDNQEsghaCMXS8YFlxPSo

# GET https://www.googleapis.com/customsearch/v1?key=INSERT_YOUR_API_KEY&cx=017576662512468239146:omuauf_lfve&q=lectures

import requests
import pandas as pd
import sys
import json
# Set the endpoint URL
url = "https://www.googleapis.com/customsearch/v1"

# Get the argument value
script_argument = sys.argv[1]
# Set the query parameters
arg = "python"
params = {
    "key": "AIzaSyChcKAIWtx3WIoDNQEsghaCMXS8YFlxPSo",
    "cx": "017576662512468239146:omuauf_lfve",
    "q": script_argument
}

# Send a GET request to the API
response = requests.get(url, params=params)

# Check if the request was successful (HTTP status code 200)
if response.status_code == 200:
    # Parse the response JSON
    data = response.json()
     # Extract the relevant information from the response
    items = data.get("items", [])

    # Convert the list of items to a DataFrame
    df = pd.DataFrame(items)
    
else:
    # Handle the error
    response.status_code
    
df=df.drop(columns = ['cacheId','formattedUrl','htmlFormattedUrl','mime','fileFormat','labels','pagemap'])


json_output = df.to_json(orient='records')
#print(json_output )

data = json.loads(json_output)

# Extract relevant information from all elements
results = []
for element in data:
    title = element.get('title', '')
    link = element.get('link', '')
    snippet = element.get('snippet', '')

    # Create a dictionary with the extracted information
    result = {'title': title, 'link': link, 'snippet': snippet}
    results.append(result)

# Convert the list of dictionaries to a JSON string
results_json = json.dumps(results, indent=2)

# Print the JSON string
print(results_json)
# Out:
# [
#   {
#     "title": "https://www.cis.upenn.edu/~myatskar/teaching/cis53...",
#     "link": "https://www.cis.upenn.edu/~myatskar/teaching/cis530_fa21//homework/python-and-bash/python_questions.py",
#     "snippet": null
#   },
#   {
#     "title": "John's Bash for NLP tutorial, basics - UPenn CIS",
#     "link": "https://www.cis.upenn.edu/~myatskar/teaching/cis530_fa21//tutorials/2017-03-06-bash-for-nlp-tutorial-basic.html",
#     "snippet": "Dec 6, 2021 ... As we said in use bash when, we frequently use bash to manipulate a Unix file system. The unix filesystem is a rooted tree-like data structure."
#   }
# ]
