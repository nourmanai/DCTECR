# %%
pip uninstall numpy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyqt5<5.13 pyqtwebengine<5.13
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Le fichier sp‚cifi‚ est introuvable.

# %%
pip install apify --user
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\nour\anaconda3\lib\site-packages)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: apify in c:\users\nour\appdata\roaming\python\python38\site-packages (1.1.4)
# Requirement already satisfied: aiofiles>=22.1.0 in c:\users\nour\appdata\roaming\python\python38\site-packages (from apify) (23.2.1)
# Requirement already satisfied: aioshutil>=1.0 in c:\users\nour\appdata\roaming\python\python38\site-packages (from apify) (1.3)
# Requirement already satisfied: apify-client~=1.4.0 in c:\users\nour\appdata\roaming\python\python38\site-packages (from apify) (1.4.1)
# Requirement already satisfied: apify-shared~=1.0.2 in c:\users\nour\appdata\roaming\python\python38\site-packages (from apify) (1.0.2)
# Requirement already satisfied: colorama>=0.4.6 in c:\users\nour\appdata\roaming\python\python38\site-packages (from apify) (0.4.6)
# Requirement already satisfied: cryptography>=39.0.0 in c:\users\nour\appdata\roaming\python\python38\site-packages (from apify) (41.0.3)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\nour\appdata\roaming\python\python38\site-packages (from apify) (0.25.0)
# Requirement already satisfied: psutil>=5.9.5 in c:\users\nour\anaconda3\lib\site-packages (from apify) (5.9.5)
# Requirement already satisfied: pyee>=9.0.0 in c:\users\nour\appdata\roaming\python\python38\site-packages (from apify) (11.0.0)
# Requirement already satisfied: sortedcollections>=2.0.1 in c:\users\nour\anaconda3\lib\site-packages (from apify) (2.1.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\nour\anaconda3\lib\site-packages (from apify) (4.7.1)
# Requirement already satisfied: websockets>=10.1 in c:\users\nour\anaconda3\lib\site-packages (from apify) (10.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\nour\anaconda3\lib\site-packages (from cryptography>=39.0.0->apify) (1.14.0)
# Requirement already satisfied: certifi in c:\users\nour\anaconda3\lib\site-packages (from httpx>=0.24.1->apify) (2020.6.20)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in c:\users\nour\appdata\roaming\python\python38\site-packages (from httpx>=0.24.1->apify) (0.18.0)
# Requirement already satisfied: idna in c:\users\nour\anaconda3\lib\site-packages (from httpx>=0.24.1->apify) (2.10)
# Requirement already satisfied: sniffio in c:\users\nour\anaconda3\lib\site-packages (from httpx>=0.24.1->apify) (1.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\nour\anaconda3\lib\site-packages (from sortedcollections>=2.0.1->apify) (2.2.2)
# Requirement already satisfied: pycparser in c:\users\nour\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=39.0.0->apify) (2.20)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\nour\appdata\roaming\python\python38\site-packages (from httpcore<0.19.0,>=0.18.0->httpx>=0.24.1->apify) (4.0.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\nour\appdata\roaming\python\python38\site-packages (from httpcore<0.19.0,>=0.18.0->httpx>=0.24.1->apify) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\nour\appdata\roaming\python\python38\site-packages (from anyio<5.0,>=3.0->httpcore<0.19.0,>=0.18.0->httpx>=0.24.1->apify) (1.1.3)

# %%
# Apify SDK - toolkit for building Apify Actors (Read more at https://docs.apify.com/sdk/python).
from apify import Actor
# Requests - library for making HTTP requests in Python (Read more at https://requests.readthedocs.io)
import requests
# Beautiful Soup - library for pulling data out of HTML and XML files (Read more at https://www.crummy.com/software/BeautifulSoup/bs4/doc)
from bs4 import BeautifulSoup

async def main():
    async with Actor:
        # Structure of input is defined in input_schema.json
        actor_input = await Actor.get_input() or {}
        url = actor_input.get('url')

        # Fetch the HTML content of the page.
        response = requests.get(url)

        # Parse the HTML content using Beautiful Soup.
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract all headings from the page (tag name and text).
        headings = []
        for heading in soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6']):
            heading_object = { 'level': heading.name, 'text': heading.text }
            print('Extracted heading', heading_object)
            headings.append(heading_object)

        # Save headings to Dataset - a table-like storage.
        await Actor.push_data(headings)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-8255db605bb8> in <module>
#       1 # Apify SDK - toolkit for building Apify Actors (Read more at https://docs.apify.com/sdk/python).
# ----> 2 from apify import Actor
#       3 # Requests - library for making HTTP requests in Python (Read more at https://requests.readthedocs.io)
#       4 import requests
#       5 # Beautiful Soup - library for pulling data out of HTML and XML files (Read more at https://www.crummy.com/software/BeautifulSoup/bs4/doc)
#
# ~\AppData\Roaming\Python\Python38\site-packages\apify\__init__.py in <module>
#       1 from importlib import metadata
#       2
# ----> 3 from .actor import Actor
#       4 from .config import Configuration
#       5 from .proxy_configuration import ProxyConfiguration, ProxyInfo
#
# ~\AppData\Roaming\Python\Python38\site-packages\apify\actor.py in <module>
#      14
#      15 from ._crypto import _decrypt_input_secrets, _load_private_key
# ---> 16 from ._memory_storage import MemoryStorageClient
#      17 from ._utils import (
#      18     _fetch_and_parse_env_var,
#
# ~\AppData\Roaming\Python\Python38\site-packages\apify\_memory_storage\__init__.py in <module>
# ----> 1 from .memory_storage_client import MemoryStorageClient
#       2
#       3 __all__ = ['MemoryStorageClient']
#
# ~\AppData\Roaming\Python\Python38\site-packages\apify\_memory_storage\memory_storage_client.py in <module>
#      13
#      14 from .._utils import _maybe_parse_bool
# ---> 15 from .resource_clients.dataset import DatasetClient
#      16 from .resource_clients.dataset_collection import DatasetCollectionClient
#      17 from .resource_clients.key_value_store import KeyValueStoreClient
#
# ~\AppData\Roaming\Python\Python38\site-packages\apify\_memory_storage\resource_clients\__init__.py in <module>
#       3 from .dataset import DatasetClient
#       4 from .dataset_collection import DatasetCollectionClient
# ----> 5 from .key_value_store import KeyValueStoreClient
#       6 from .key_value_store_collection import KeyValueStoreCollectionClient
#       7 from .request_queue import RequestQueueClient
#
# ~\AppData\Roaming\Python\Python38\site-packages\apify\_memory_storage\resource_clients\key_value_store.py in <module>
#      26 )
#      27 from ...consts import DEFAULT_API_PARAM_LIMIT, _StorageTypes
# ---> 28 from ...log import logger
#      29 from ..file_storage_utils import _update_metadata
#      30 from .base_resource_client import BaseResourceClient
#
# ~\AppData\Roaming\Python\Python38\site-packages\apify\log.py in <module>
#       5 from typing import Any, Dict
#       6
# ----> 7 from colorama import Fore, Style, just_fix_windows_console
#       8
#       9 from apify_shared.utils import ignore_docs
#
# ImportError: cannot import name 'just_fix_windows_console' from 'colorama' (C:\Users\NOUR\anaconda3\lib\site-packages\colorama\__init__.py)

# %%
import asyncio
import logging

from apify.log import ActorLogFormatter


# Set up logging of messages from the Apify SDK
handler = logging.StreamHandler()
handler.setFormatter(ActorLogFormatter())

apify_client_logger = logging.getLogger('apify_client')
apify_client_logger.setLevel(logging.INFO)
apify_client_logger.addHandler(handler)

apify_logger = logging.getLogger('apify')
apify_logger.setLevel(logging.DEBUG)
apify_logger.addHandler(handler)

asyncio.run(main())
