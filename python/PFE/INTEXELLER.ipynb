# %%
# API Key 
# 2a6a82dc-5b31-47c3-ac81-1d38de35479c
##################### Clustering ############################
api_url = "http://api.intellexer.com/clusterizeText?apikey=2a6a82dc-5b31-47c3-ac81-1d38de35479c&conceptsRestriction=10&fullTextTrees=true"
sample_text = "Free and proprietary machine learning APIs are a good way to get started AI projects without much efforts. Although there are hard to find high quality and performance APIs, like Language APIs."
def print_tree(node, height):
	for i in range(0, height):
		print ("\t"),
	print (node.get('text'))
	children = node.get('children')
	height += 1
	for child in children:
		print_tree(child, height)

# print response results
def print_response(response):
	print ("Concept tree:")
	print_tree(response.get('conceptTree'), 1)
def request_api(url, text):
	header = { 'Content-Type' : "application/octet-stream" }
	req = urllib2.Request(url, text, header)
	conn = urllib2.urlopen(req)
	try:
		json_response = json.loads(conn.read())
	finally:
		conn.close()
	print_response(json_response)

# %%
import urllib.request
import json

def request_api(url, text):
    header = {'Content-Type': "application/octet-stream"}
    req = urllib.request.Request(url, text.encode('utf-8'), header)
    conn = urllib.request.urlopen(req)
    try:
        response = conn.read().decode('utf-8')
        result = json.loads(response)
        return result
    finally:
        conn.close()

# Rest of your code...

# %%
request_api(api_url, sample_text)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 request_api(api_url, sample_text)
#
# Cell In[9], line 7, in request_api(url, text)
#       5 header = {'Content-Type': "application/octet-stream"}
#       6 req = urllib.request.Request(url, text.encode('utf-8'), header)
# ----> 7 conn = urllib.request.urlopen(req)
#       8 try:
#       9     response = conn.read().decode('utf-8')
#
# File ~\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
# ...

# %%
##################### Named Entity Recognizer ############################

# %%
# possible named entities types 
ners = ["Unknown", "Person", "Organization", "Location", "Title", "Position", "Age", \
	"Date", "Duration", "Nationality", "Event", "Url", "MiscellaneousLocation"]

# sample text
sample_text = "Eyal Shaked was appointed General Manager of the Optical Networks Division in October 2005."

# set the URL for POST request and specify API key for authorization purposes (change YourAPIKey to the Intellexer API key)
api_url = "http://api.intellexer.com/recognizeNeText?apikey=2a6a82dc-5b31-47c3-ac81-1d38de35479c&loadNamedEntities=true&loadRelationsTree=true&loadSentences=true"

# print relations tree
def print_tree(node, height):
	for i in range(0, height):
		print ("\t"),
	print (node.get('text'))
	children = node.get('children')
	height += 1
	for child in children:
		print_tree(child, height)


# print information about detected named entities
def print_response(response):
	print ("Detected Named Entities:")
	entities = response.get('entities')
	for entity in entities:
		print ("\t", ners[entity.get('type')], ": ", entity.get('text'))
	# print relations tree
	print ("Relations tree:");
	print_tree(response.get('relationsTree'), 1)

import urllib.request
import json

def request_api(url, text):
    header = {'Content-Type': "application/octet-stream"}
    req = urllib.request.Request(url, text.encode('utf-8'), header)
    conn = urllib.request.urlopen(req)
    try:
        response = conn.read().decode('utf-8')
        result = json.loads(response)
        return result
    finally:
        conn.close()
	


request_api(api_url, sample_text)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 48
#      43     finally:
#      44         conn.close()
# ---> 48 request_api(api_url, sample_text)
#
# Cell In[11], line 38, in request_api(url, text)
#      36 header = {'Content-Type': "application/octet-stream"}
#      37 req = urllib.request.Request(url, text.encode('utf-8'), header)
# ---> 38 conn = urllib.request.urlopen(req)
#      39 try:
#      40     response = conn.read().decode('utf-8')
#
# File ~\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
# ...

# %%
##################### Sentiment analyser ############################

# %%
# list of reviews in JSON format
reviews = """[
		{
			\"id\": \"snt1\",
			\"text\": \"Very good comfort and very kind service in this modern hotel, very close to Chennai Airport.\"
		},
		{
			\"id\": \"snt2\",
			\"text\": \"The service and restaurants are excellent, especially like the Samudra restaurant providing lots of tempting alternatives.\"
		},
		{
			\"id\": \"snt3\",
			\"text\": \"Often travel to Chennai on business and this was the first time I tried the Trident, Chennai. I\'ll be staying here on all future trips. Excelllent service and the food was terrific.\"
		},
		{
			\"id\": \"snt4\",
			\"text\": \"The ambiance of the restaurants is very poor, Cinnamon is more laid back, Samudra is more exclusive. Food is excellent and of course with Trident totally safe. Staff are very warm and welcoming. The rooms are not brand new.\"
		}
			]"""

# set the URL for POST request, specify url, parameters for information processing, ontology for opinion categorization and API key for authorization purposes (change YourAPIKey to the Intellexer API key)

api_url = "http://api.intellexer.com/analyzeSentiments?apikey=2a6a82dc-5b31-47c3-ac81-1d38de35479c&ontology=hotels&loadSentences=true"

# print categorized opinions
def print_tree_SentimentAnalyzer(node, height):
	for i in range(0, height):
		print ("\t"),
	print (node.get("t")),
	if node.get('w') != 0:
		print ("\t", node.get('w'))
	else:
		print ("\t")
	children = node.get('children')
	height += 1
	for child in children:
		print_tree_SentimentAnalyzer(child, height)

# print response results
def print_response_SentimentAnalyzer(response):
	print ("Sentences with sentiment objects and phrases:");
	sentences = response.get('sentences')
	for sent in sentences:
		print ("Sentence Weight = ", sent.get('w'), "\t", sent.get('text').encode('utf-8'))
	#print categorized opinions
	print ("\nCategorized Opinions with sentiment polarity (positive/negative)")
	print_tree_SentimentAnalyzer(response.get('opinions'), 0)

# create request to the Sentiment Analyzer API service
def request_api_SentimentAnalyzer(url, data):
	header = { 'Content-Type' : "application/json" }
	json_data = json.dumps(data).encode('utf-8')  # Encode data as JSON bytes
	req = urllib.request.Request(url,data=json_data, headers=header)
	conn = urllib.request.urlopen(req)
	try:
		json_response = json.loads(conn.read().decode('utf-8'))
		response = conn.read().decode('utf-8')

	finally:
		conn.close()
	print_response_SentimentAnalyzer(json_response)
# perform the request

#req = urllib.Request(url, data, header)
#conn = urllib.urlopen(req)
request_api_SentimentAnalyzer(api_url, json.loads(reviews))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[12], line 66
#      61 	print_response_SentimentAnalyzer(json_response)
#      62 # perform the request
#      63
#      64 #req = urllib.Request(url, data, header)
#      65 #conn = urllib.urlopen(req)
# ---> 66 request_api_SentimentAnalyzer(api_url, json.loads(reviews))
#
# Cell In[12], line 54, in request_api_SentimentAnalyzer(url, data)
#      52 json_data = json.dumps(data).encode('utf-8')  # Encode data as JSON bytes
#      53 req = urllib.request.Request(url,data=json_data, headers=header)
# ---> 54 conn = urllib.request.urlopen(req)
#      55 try:
#      56 	json_response = json.loads(conn.read().decode('utf-8'))
#
# File ~\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# ...

# %%
##################### comparison urls ############################

# %%
# set the URL for GET request, specify comparison urls and API key for authorization purposes (change YourAPIKey to the Intellexer API key)
api_url = "http://api.intellexer.com/compareUrls?apikey=2a6a82dc-5b31-47c3-ac81-1d38de35479c&url1=http://www.infoplease.com/biography/var/barackobama.html&url2=http://millercenter.org/president/biography/obama-life-in-brief&useCache=false"

# print response results
def print_response_Comparator(response):
	print ("Proximity between")
	print (response.get('document1').get('title'), " and ", response.get('document2').get('title'), " is ", response.get('proximity'))

# create request to the Comparator API service
def request_api_URLComparator(url):
	req = urllib.request.Request(url, None)
	conn = urllib.request.urlopen(req)
	try:
		json_response = json.loads(conn.read())
	finally:
		conn.close()
	print_response_Comparator(json_response)

# perform the request
request_api_URLComparator(api_url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 20
#      17 	print_response_Comparator(json_response)
#      19 # perform the request
# ---> 20 request_api_URLComparator(api_url)
#
# Cell In[13], line 12, in request_api_URLComparator(url)
#      10 def request_api_URLComparator(url):
#      11 	req = urllib.request.Request(url, None)
# ---> 12 	conn = urllib.request.urlopen(req)
#      13 	try:
#      14 		json_response = json.loads(conn.read())
#
# File ~\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
# ...

# %%
### payant trial ended !!
