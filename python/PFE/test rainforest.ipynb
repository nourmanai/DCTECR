# %%
import requests

url = "https://rainforest2.p.rapidapi.com/request"

querystring = {"type":"offers","amazon_domain":"amazon.com","asin":"B073JYC4XM","offers_prime":"false","offers_free_shipping":"false","offers_condition_new":"false","offers_condition_used_like_new":"false","offers_condition_used_very_good":"false","offers_condition_used_good":"false","offers_condition_used_acceptable":"false","show_different_asins":"false"}

headers = {
	"X-RapidAPI-Key": "a619bfcad9msh56f2f66563cadb4p186d94jsn0a59d4ce6269",
	"X-RapidAPI-Host": "rainforest2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'message': 'API Request failed due to Provider configuration error: The API response body transformation failed to parse content-type application/json. Please contact the API Provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}

# %%
import requests

url = "https://rainforest2.p.rapidapi.com/request"

querystring = {"type":"product","amazon_domain":"amazon.com","asin":"B073JYC4XM"}

headers = {
	"X-RapidAPI-Key": "a619bfcad9msh56f2f66563cadb4p186d94jsn0a59d4ce6269",
	"X-RapidAPI-Host": "rainforest2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

# %%
import requests

url = "https://rainforest2.p.rapidapi.com/request"

querystring = {"type":"reviews","amazon_domain":"amazon.com","asin":"B073JYC4XM"}

headers = {
	"X-RapidAPI-Key": "a619bfcad9msh56f2f66563cadb4p186d94jsn0a59d4ce6269",
	"X-RapidAPI-Host": "rainforest2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
